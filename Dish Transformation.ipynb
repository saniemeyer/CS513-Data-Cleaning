# %% [markdown]
# # CS 416 Phase II - PySpark Cleaning of the Dish.name

# %% [markdown]
# ### Configure access to the files stored in our Azure Blob Container

# %%
storage_account_name = "stuscdsprdbia"
storage_account_access_key = ""
spark.conf.set("fs.azure.account.key."+storage_account_name+".blob.core.windows.net", storage_account_access_key)
blob_container = "test-data"
file_path = "wasbs://" + blob_container + "@" + storage_account_name + ".blob.core.windows.net/menus/"

# %% [markdown]
# ### Load the .csv files into Spark DataFrames

# %%
#menu_df = spark.read.format("csv").option("inferSchema", "true").option("header", "true").load(file_path + "Menu.csv")
#menu_page_df = spark.read.format("csv").option("inferSchema", "true").option("header", "true").load(file_path + "MenuPage.csv")
menu_item_df = spark.read.format("csv").option("inferSchema", "true").option("header", "true").load(file_path + "MenuItem.csv")
dish_df = spark.read.format("csv").option("inferSchema", "true").option("header", "true").load(file_path + "Dish.csv")

# %% [markdown]
# ### Create temp views so that we can query the data in SQL

# %%
#menu_df.createOrReplaceTempView("menu")
#menu_page_df.createOrReplaceTempView("menu_page")
menu_item_df.createOrReplaceTempView("menu_item")
dish_df.createOrReplaceTempView("dish")

# %% [markdown]
# ### Remove any Dish records not found in MenuItem. Also exclude any Dish records with a blank or NULL name.

# %%
dish_df_existing = spark.sql("SELECT * FROM dish WHERE EXISTS (SELECT 1 FROM menu_item WHERE dish.id = menu_item.dish_id) AND dish.name IS NOT NULL AND TRIM(dish.name) <> ''")

# %% [markdown]
# ### Remove non-alpha characters and multiple spaces

# %%
from pyspark.sql.functions import regexp_replace
dish_df_alpha = dish_df_existing.withColumn("name_alpha", regexp_replace("name", r"[^a-zA-Z\s]", ""))
dish_df_alpha = dish_df_alpha.withColumn("name_alpha", regexp_replace("name_alpha", " +", " "))

# %% [markdown]
# ### Tokenize the alphabetic name

# %%
from pyspark.ml.feature import Tokenizer, StopWordsRemover
tokenizer = Tokenizer(inputCol="name_alpha", outputCol="tokens")
tokenized_df = tokenizer.transform(dish_df_alpha)

# %% [markdown]
# ### Remove Stop Words in English, Spanish, French, and German, along with our custom list of stop words

# %%
from pyspark.sql.functions import concat_ws, col, trim
stopwordList = ["order","cup","restaurant"] # custom stop words
english = StopWordsRemover().getStopWords()
spanish = StopWordsRemover.loadDefaultStopWords('spanish')
french = StopWordsRemover.loadDefaultStopWords('french')
german = StopWordsRemover.loadDefaultStopWords('german')
stopwordList.extend(english)
stopwordList.extend(spanish)
stopwordList.extend(french)
stopwordList.extend(german)
stopwordList = list(set(stopwordList))
remover = StopWordsRemover(inputCol="tokens", outputCol="words", stopWords=stopwordList)
words_df = remover.transform(tokenized_df)
words_df = words_df.withColumn("words_string", trim(concat_ws("", col("words"))))
words_df = words_df.where("words_string <> ''")
words_df.select("name_alpha","tokens","words","words_string").limit(1000).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name_alpha</th><th>tokens</th><th>words</th><th>words_string</th></tr></thead><tbody><tr><td>Oyster cocktail</td><td>List(oyster, cocktail)</td><td>List(oyster, cocktail)</td><td>oystercocktail</td></tr><tr><td>Stewed Tripe with Cream sauce</td><td>List(stewed, tripe, with, cream, sauce)</td><td>List(stewed, tripe, cream, sauce)</td><td>stewedtripecreamsauce</td></tr><tr><td>Cream Cheese</td><td>List(cream, cheese)</td><td>List(cream, cheese)</td><td>creamcheese</td></tr><tr><td>Lamb Chops Broiled Plain</td><td>List(lamb, chops, broiled, plain)</td><td>List(lamb, chops, broiled, plain)</td><td>lambchopsbroiledplain</td></tr><tr><td>New asparagus</td><td>List(new, asparagus)</td><td>List(new, asparagus)</td><td>newasparagus</td></tr><tr><td>Fresh milk</td><td>List(fresh, milk)</td><td>List(fresh, milk)</td><td>freshmilk</td></tr><tr><td>Cup consomme hot or cold</td><td>List(cup, consomme, hot, or, cold)</td><td>List(consomme, hot, cold)</td><td>consommehotcold</td></tr><tr><td>Succotash</td><td>List(succotash)</td><td>List(succotash)</td><td>succotash</td></tr><tr><td>Baltimore broil</td><td>List(baltimore, broil)</td><td>List(baltimore, broil)</td><td>baltimorebroil</td></tr><tr><td>Russia Caviar</td><td>List(russia, caviar)</td><td>List(russia, caviar)</td><td>russiacaviar</td></tr><tr><td>Boiled Bermuda onions cream sauce</td><td>List(boiled, bermuda, onions, cream, sauce)</td><td>List(boiled, bermuda, onions, cream, sauce)</td><td>boiledbermudaonionscreamsauce</td></tr><tr><td>Cantrell Cochrane Ginger Ale</td><td>List(cantrell, cochrane, ginger, ale)</td><td>List(cantrell, cochrane, ginger, ale)</td><td>cantrellcochranegingerale</td></tr><tr><td>Shredded Wheat Biscuit</td><td>List(shredded, wheat, biscuit)</td><td>List(shredded, wheat, biscuit)</td><td>shreddedwheatbiscuit</td></tr><tr><td>Soup a la Genevoise</td><td>List(soup, a, la, genevoise)</td><td>List(soup, genevoise)</td><td>soupgenevoise</td></tr><tr><td>Broiled Celery Sauce</td><td>List(broiled, celery, sauce)</td><td>List(broiled, celery, sauce)</td><td>broiledcelerysauce</td></tr><tr><td>Watermelons</td><td>List(watermelons)</td><td>List(watermelons)</td><td>watermelons</td></tr><tr><td>Trois oeufs brouilles</td><td>List(trois, oeufs, brouilles)</td><td>List(trois, oeufs, brouilles)</td><td>troisoeufsbrouilles</td></tr><tr><td>American Cheese Sandwich</td><td>List(american, cheese, sandwich)</td><td>List(american, cheese, sandwich)</td><td>americancheesesandwich</td></tr><tr><td>Crab Meat</td><td>List(crab, meat)</td><td>List(crab, meat)</td><td>crabmeat</td></tr><tr><td>Vanilla eclair</td><td>List(vanilla, eclair)</td><td>List(vanilla, eclair)</td><td>vanillaeclair</td></tr><tr><td>Poisson en sauce et pommes de terre</td><td>List(poisson, en, sauce, et, pommes, de, terre)</td><td>List(poisson, sauce, pommes, terre)</td><td>poissonsaucepommesterre</td></tr><tr><td>Windsor</td><td>List(windsor)</td><td>List(windsor)</td><td>windsor</td></tr><tr><td>Canadian Club</td><td>List(canadian, club)</td><td>List(canadian, club)</td><td>canadianclub</td></tr><tr><td>Patates Mexicaine</td><td>List(patates, mexicaine)</td><td>List(patates, mexicaine)</td><td>patatesmexicaine</td></tr><tr><td>tea</td><td>List(tea)</td><td>List(tea)</td><td>tea</td></tr><tr><td>Hot Slaw</td><td>List(hot, slaw)</td><td>List(hot, slaw)</td><td>hotslaw</td></tr><tr><td>Plain Rice Pudding</td><td>List(plain, rice, pudding)</td><td>List(plain, rice, pudding)</td><td>plainricepudding</td></tr><tr><td>Wheatena</td><td>List(wheatena)</td><td>List(wheatena)</td><td>wheatena</td></tr><tr><td>Tenderloin a la bordelaise or bearnaise</td><td>List(tenderloin, a, la, bordelaise, or, bearnaise)</td><td>List(tenderloin, bordelaise, bearnaise)</td><td>tenderloinbordelaisebearnaise</td></tr><tr><td>Fresh Codfish</td><td>List(fresh, codfish)</td><td>List(fresh, codfish)</td><td>freshcodfish</td>< ...

the</td></tr><tr><td>abb</td></tr><tr><td>abbacchio</td></tr><tr><td>abbachio</td></tr><tr><td>abbamochashauntanawsuck</td></tr><tr><td>abbaye</td></tr><tr><td>abbazia</td></tr><tr><td>abbaziagebck</td></tr><tr><td>abbe</td></tr><tr><td>abbey</td></tr><tr><td>abbeys</td></tr><tr><td>abbisine</td></tr><tr><td>abbissine</td></tr><tr><td>abbiustolita</td></tr><tr><td>abboc</td></tr><tr><td>abboccato</td></tr><tr><td>abborre</td></tr><tr><td>abbots</td></tr><tr><td>abbotsford</td></tr><tr><td>abbotts</td></tr><tr><td>abby</td></tr><tr><td>abbysinienne</td></tr><tr><td>abc</td></tr><tr><td>abchovies</td></tr><tr><td>abdour</td></tr><tr><td>abdulla</td></tr><tr><td>abdullah</td></tr><tr><td>abe</td></tr><tr><td>abegg</td></tr><tr><td>abel</td></tr><tr><td>abelina</td></tr><tr><td>abenakis</td></tr><tr><td>abend</td></tr><tr><td>abendessen</td></tr><tr><td>abendplatte</td></tr><tr><td>abends</td></tr><tr><td>aberdeen</td></tr><tr><td>aberlour</td></tr><tr><td>abernethy</td></tr><tr><td>abescon</td></tr><tr><td>abf</td></tr><tr><td>abfl</td></tr><tr><td>abflambierte</td></tr><tr><td>abfller</td></tr><tr><td>abfllung</td></tr><tr><td>abflmkorkbrdjuliusspitalkellerei</td></tr><tr><td>abfuellung</td></tr><tr><td>abfullung</td></tr><tr><td>abgang</td></tr><tr><td>abgebr</td></tr><tr><td>abgebraten</td></tr><tr><td>abgebraunt</td></tr><tr><td>abgebraunte</td></tr><tr><td>abgebraunten</td></tr><tr><td>abgebraut</td></tr><tr><td>abgebrmayonnaisesalat</td></tr><tr><td>abgebrsalat</td></tr><tr><td>abgebrunt</td></tr><tr><td>abgefullt</td></tr><tr><td>abgeloscht</td></tr><tr><td>abgerostetes</td></tr><tr><td>abgerstet</td></tr><tr><td>abgerundet</td></tr><tr><td>abgeschmeckt</td></tr><tr><td>abgeschmelzt</td></tr><tr><td>abgeschmelzte</td></tr><tr><td>abgeschmolzen</td></tr><tr><td>abgeschmolzene</td></tr><tr><td>abgestimmt</td></tr><tr><td>abheschmeckt</td></tr><tr><td>abigail</td></tr><tr><td>abingdon</td></tr><tr><td>abir</td></tr><tr><td>abisante</td></tr><tr><td>abl</td></tr><tr><td>ablaze</td></tr><tr><td>able</td></tr><tr><td>ablekage</td></tr><tr><td>aboard</td></tr><tr><td>aboetir</td></tr><tr><td>abolu</td></tr><tr><td>abon</td></tr><tr><td>aborns</td></tr><tr><td>aboukir</td></tr><tr><td>abrahams</td></tr><tr><td>abrato</td></tr><tr><td>abrau</td></tr><tr><td>abreu</td></tr><tr><td>abricossc</td></tr><tr><td>abricot</td></tr><tr><td>abricotine</td></tr><tr><td>abricotineglass</td></tr><tr><td>abricotines</td></tr><tr><td>abricots</td></tr><tr><td>abricotte</td></tr><tr><td>abrikos</td></tr><tr><td>abrikoser</td></tr><tr><td>abriko ...

# %% [markdown]
# ### Copy files to ADLS Gen 2

# %%
dbutils.fs.cp ("dbfs:/user/shaun_n/data/Dish_name.csv", file_path + "Dish_name.csv")
# Out:
# Out[20]: True

# %%
dbutils.fs.cp ("dbfs:/user/shaun_n/data/Dish_id_name.csv", file_path + "Dish_id_name.csv")
# Out:
# Out[21]: True
